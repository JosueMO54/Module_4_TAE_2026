# %% [markdown]
# # **Convolución para MNIST-1D**
#
# Este cuaderno explora una red convolucional 1D para MNIST-1D.
#
# Ejecuta las celdas en orden. En varios lugares verás la palabra "TAREA": sigue esas instrucciones, anticipa qué ocurrirá o escribe el código necesario para completar las funciones.

# %%
# Ejecuta esta celda una vez si necesitas instalar el repositorio MNIST-1D
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-y7jeki4j
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-y7jeki4j
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from mnist1d==0.0.2.post16) (2.1.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.13/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests->mnist1d==0.0.2.post16) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# Las entradas y salidas de entrenamiento y prueba están en
# data['x'], data['y'], data['x_test'] y data['y_test']
print("Samples in training set: {}".format(len(data['y'])))
print("Samples in test set: {}".format(len(data['y_test'])))
print("Length of each sample: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Samples in training set: 4000
# Samples in test set: 1000
# Length of each sample: 40

# %%
# Carga los datos
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Muestra los tamaños
print("Training data: %d samples (columns), each with %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d samples (columns), each with %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Training data: 4000 samples (columns), each with 40 dimensions (rows)
# Validation data: 1000 samples (columns), each with 40 dimensions (rows)

# %% [markdown]
# Define la red

# %%
# Estos datos tienen 40 dimensiones de entrada y 10 dimensiones de salida
# Las entradas corresponden a los 40 desplazamientos de la plantilla MNIST-1D.
D_i = 40
# Las salidas corresponden a los 10 dígitos
D_o = 10


# TAREA: crea un modelo con las siguientes capas
# 1. Capa convolucional (entrada: longitud 40 y 1 canal; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 2. ReLU
# 3. Capa convolucional (entrada: longitud 19 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 4. ReLU
# 5. Capa convolucional (entrada: longitud 9 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 6. ReLU
# 7. Aplanamiento (convierte 4x15) a longitud 60
# 8. Capa lineal (tamaño de entrada = 60, tamaño de salida = 10)
# Documentación útil:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# TEN EN CUENTA QUE LAS CAPAS CONVOLUCIONALES NECESITAN RECIBIR EL NÚMERO DE CANALES DE ENTRADA COMO PARÁMETRO
# Y NO EL TAMAÑO DE LA ENTRADA.

# Reemplaza la siguiente función:
model = nn.Sequential(
    # 1. Primera capa convolucional
    nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding=0),
    # 2. Activación ReLU
    nn.ReLU(),
    # 3. Segunda capa convolucional
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    # 4. Activación ReLU
    nn.ReLU(),
    # 5. Tercera capa convolucional
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    # 6. Activación ReLU
    nn.ReLU(),
    # 7. Aplanamiento a vector de longitud 60 (15 canales x 4 longitud restante)
    nn.Flatten(),
    # 8. Capa lineal final hacia las 10 clases
    nn.Linear(in_features=60, out_features=10)
)

# %%
# Inicialización de pesos de He
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# Elige la función de pérdida de entropía cruzada
loss_function = nn.CrossEntropyLoss()
# Construye el optimizador SGD e inicializa la tasa de aprendizaje y el momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# Objeto que reduce la tasa de aprendizaje a la mitad cada 20 épocas
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# Crea los tensores de datos y guárdalos en un DataLoader
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# Carga los datos en una clase que crea los lotes
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Inicializa los pesos del modelo
model.apply(weights_init)

# Recorre el conjunto de datos n_epoch veces
n_epoch = 100
# Guarda la pérdida y el porcentaje de error en cada época
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # Recorre los lotes
  for i, data in enumerate(data_loader):
    # Recupera entradas y etiquetas de este lote
    x_batch, y_batch = data
    # Reinicia los gradientes de los parámetros
    optimizer.zero_grad()
    # Paso hacia adelante: calcula la salida del modelo
    pred = model(x_batch[:,None,:])
    # Calcula la pérdida
    loss = loss_function(pred, y_batch)
    # Paso hacia atrás
    loss.backward()
    # Actualización SGD
    optimizer.step()

  # Ejecuta todo el conjunto de datos para obtener estadísticas; normalmente no harías esto
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, training loss {losses_train[epoch]:.6f}, training error {errors_train[epoch]:3.2f}, validation loss {losses_val[epoch]:.6f}, validation error {errors_val[epoch]:3.2f}')

  # Indica al programador que evalúe si debe actualizar la tasa de aprendizaje
  scheduler.step()

# Grafica los resultados
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='entrenamiento')
ax.plot(errors_val,'b-',label='validación')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.legend()
plt.show()
# Out:
# Epoch     0, training loss 2.266168, training error 83.53, validation loss 2.263736, validation error 82.90
# Epoch     1, training loss 1.823282, training error 74.05, validation loss 1.829162, validation error 74.90
# Epoch     2, training loss 1.477278, training error 60.08, validation loss 1.489908, validation error 62.60
# Epoch     3, training loss 1.335123, training error 55.45, validation loss 1.348572, validation error 56.90
# Epoch     4, training loss 1.271665, training error 53.10, validation loss 1.279294, validation error 53.60
# Epoch     5, training loss 1.186371, training error 48.08, validation loss 1.219105, validation error 50.30
# Epoch     6, training loss 1.239330, training error 51.40, validation loss 1.282974, validation error 55.40
# Epoch     7, training loss 1.022889, training error 41.80, validation loss 1.071114, validation error 45.80
# Epoch     8, training loss 1.184737, training error 48.47, validation loss 1.253043, validation error 50.40
# Epoch     9, training loss 0.890105, training error 37.70, validation loss 0.957345, validation error 41.00
# Epoch    10, training loss 0.872820, training error 34.70, validation loss 0.967555, validation error 41.00
# Epoch    11, training loss 0.932207, training error 34.35, validation loss 1.009075, validation error 35.70
# Epoch    12, training loss 0.661982, training error 24.78, validation loss 0.733719, validation error 28.70
# Epoch    13, training loss 0.635645, training error 24.20, validation loss 0.694906, validation error 28.20
# Epoch    14, training loss 0.527504, training error 20.03, validation loss 0.583420, validation error 21.40
# Epoch    15, training loss 0.500815, training error 19.00, validation loss 0.570515, validation error 21.10
# Epoch    16, training loss 0.397784, training error 14.10, validation loss 0.470302, validation error 16.50
# Epoch    17, training loss 0.410990, training error 15.32, validation loss 0.508848, validation error 19.20
# Epoch    18, training loss 0.331974, training error 12.10, validation loss 0.432652, validation error 15.90
# Epoch    19, training loss 0.296569, training error 10.47, validation loss 0.403302, validation error 13.50
# Epoch    20, training loss 0.247174, training error 8.50, validation loss 0.382591, validation error 13.20
# Epoch    21, training loss 0.277951, training error 10.12, validation loss 0.418005, validation error 13.80
# Epoch    22, training loss 0.241006, training error 8.55, validation loss 0.379403, validation error 13.60
# Epoch    23, training loss 0.222931, training error 8.03, validation loss 0.376731, validation error 12.70
# Epoch    24, training loss 0.196466, training error 6.70, validation loss 0.353916, validation error 11.60
# Epoch    25, training loss 0.213978, training error 7.57, validation loss 0.405878, validation error 13.20
# Epoch    26, training loss 0.195304, training error 6.82, validation loss 0.376814, validation error 12.60
# Epoch    27, training loss 0.178504, training error 5.97, validation loss 0.355493, validation error 12.20
# Epoch    28, training loss 0.191535, training error 6.82, validation loss 0.369972, validation error 11.10
# Epoch    29, training loss 0.172423, training error 5.85, validation loss 0.369638, validation error 12.90
# Epoch    30, training loss 0.150422, training error 4.82, validation loss 0.352094, validation error 11.30
# Epoch    31, training loss 0.150581, training error 4.95, validation loss 0.363774, validation error 11.10
# Epoch    32, training loss 0.134720, training error 4.03, validation loss 0.342925, validation error 10.50
# Epoch    33, training loss 0.155523, training error 5.25, validation loss 0.360034, validation error 10.50
# Epoch    34, training loss 0.149688, training error 4.88, validation loss 0.359414, validation error 11.10
# Epoch    35, training loss 0.135715, training error 4.80, validation loss 0.371956, validation error 10.90
# Epoch    36, training loss 0.155037, training error 5.80, validation loss 0.402164, validation error 12.00
# Epoch    37, training loss 0.118836, training error 3.88, validation loss 0.353467, validation error 10.80
# Epoch    38, training loss 0.164986, training error 6.03, validation loss 0.405321, validation error 11.00
# Epoch    39, training loss 0.138226, training error 4.55, validation loss 0.376585, validation error 11.10
# Epoch    40, training loss 0.095681, training error 2.82, validation loss 0.347158, validation error 9.80
# Epoch    41, training loss 0.091938, training error 2.78, validation loss 0.357639, validation error 10.10
# Epoch    42, training loss 0.086402, training error 2.32, validation loss 0.367839, validation error 9.90
# Epoch    43, training loss 0.081861, training error 2.15, validation loss 0.359190, validation error 9.50
# Epoch    44, training loss 0.084478, training error 2.50, validation loss 0.365036, validation error 8.90
# Epoch    45, training loss 0.087747, training error 2.40, validation loss 0.376763, validation error 10.70
# Epoch    46, training loss 0.080632, training error 2.15, validation loss 0.380660, validation error 10.30
# Epoch    47, training loss 0.085858, training error 2.53, validation loss 0.375272, validation error 9.90
# Epoch    48, training loss 0.072476, training error 1.85, validation loss 0.364031, validation error 9.70
# Epoch    49, training loss 0.072725, training error 1.68, validation loss 0.368350, validation error 10.00
# Epoch    50, training loss 0.077921, training error 2.20, validation loss 0.390606, validation error 10.20
# Epoch    51, training loss 0.068132, training error 1.70, validation loss 0.374643, validation error 9.60
# Epoch    52, training loss 0.070560, training error 1.78, validation loss 0.390807, validation error 10.60
# Epoch    53, training loss 0.072055, training error 2.12, validation loss 0.380701, validation error 10.30
# Epoch    54, training loss 0.078644, training error 2.28, validation loss 0.399076, validation error 9.20
# Epoch    55, training loss 0.070061, training error 2.03, validation loss 0.374700, validation error 10.50
# Epoch    56, training loss 0.065780, training error 1.62, validation loss 0.378466, validation error 9.10
# Epoch    57, training loss 0.065601, training error 1.78, validation loss 0.386344, validation error 9.30
# Epoch    58, training loss 0.061233, training error 1.53, validation loss 0.384383, validation error 9.80
# Epoch    59, training loss 0.064267, training error 1.47, validation loss 0.401517, validation error 10.30
# Epoch    60, training loss 0.056155, training error 1.03, validation loss 0.389741, validation error 10.00
# Epoch    61, training loss 0.054640, training error 1.05, validation loss 0.385015, validation error 9.60
# Epoch    62, training loss 0.054480, training error 1.22, validation loss 0.392483, validation error 10.00
# Epoch    63, training loss 0.055550, training error 1.07, validation loss 0.395563, validation error 9.70
# Epoch    64, training loss 0.056778, training error 1.35, validation loss 0.397850, validation error 10.00
# Epoch    65, training loss 0.051806, training error 1.03, validation loss 0.385649, validation error 9.60
# Epoch    66, training loss 0.053437, training error 1.03, validation loss 0.398292, validation error 10.00
# Epoch    67, training loss 0.053564, training error 1.05, validation loss 0.387091, validation error 9.60
# Epoch    68, training loss 0.052816, training error 1.10, validation loss 0.402841, validation error 9.70
# Epoch    69, training loss 0.053179, training error 1.07, validation loss 0.412406, validation error 9.70
# Epoch    70, training loss 0.050230, training error 0.95, validation loss 0.395879, validation error 10.00
# Epoch    71, training loss 0.051927, training error 1.20, validation loss 0.407555, validation error 9.80
# Epoch    72, training loss 0.050696, training error 1.07, validation loss 0.397277, validation error 9.90
# Epoch    73, training loss 0.047982, training error 0.85, validation loss 0.407140, validation error 9.60
# Epoch    74, training loss 0.047678, training error 0.90, validation loss 0.407082, validation error 9.70
# Epoch    75, training loss 0.046687, training error 0.78, validation loss 0.405071, validation error 9.80
# Epoch    76, training loss 0.052688, training error 1.40, validation loss 0.420838, validation error 10.30
# Epoch    77, training loss 0.045965, training error 0.93, validation loss 0.411864, validation error 9.80
# Epoch    78, training loss 0.046561, training error 0.78, validation loss 0.419606, validation error 10.00
# Epoch    79, training loss 0.045335, training error 0.80, validation loss 0.416823, validation error 9.80
# Epoch    80, training loss 0.043658, training error 0.72, validation loss 0.413759, validation error 9.80
# Epoch    81, training loss 0.043919, training error 0.75, validation loss 0.419090, validation error 9.80
# Epoch    82, training loss 0.044177, training error 0.68, validation loss 0.415870, validation error 9.90
# Epoch    83, training loss 0.044572, training error 0.75, validation loss 0.421129, validation error 9.90
# Epoch    84, training loss 0.043136, training error 0.70, validation loss 0.419067, validation error 9.70
# Epoch    85, training loss 0.042923, training error 0.78, validation loss 0.416332, validation error 9.80
# Epoch    86, training loss 0.042391, training error 0.65, validation loss 0.414184, validation error 9.80
# Epoch    87, training loss 0.042727, training error 0.72, validation loss 0.417737, validation error 9.80
# Epoch    88, training loss 0.041876, training error 0.72, validation loss 0.417506, validation error 10.00
# Epoch    89, training loss 0.043174, training error 0.75, validation loss 0.424009, validation error 9.70
# Epoch    90, training loss 0.041609, training error 0.60, validation loss 0.416834, validation error 9.70
# Epoch    91, training loss 0.042288, training error 0.75, validation loss 0.427408, validation error 10.00
# Epoch    92, training loss 0.041446, training error 0.68, validation loss 0.415122, validation error 9.90
# Epoch    93, training loss 0.041396, training error 0.70, validation loss 0.423747, validation error 9.80
# Epoch    94, training loss 0.040864, training error 0.70, validation loss 0.420395, validation error 9.80
# Epoch    95, training loss 0.040688, training error 0.65, validation loss 0.418664, validation error 10.00
# Epoch    96, training loss 0.040627, training error 0.65, validation loss 0.425451, validation error 10.00
# Epoch    97, training loss 0.040498, training error 0.70, validation loss 0.425800, validation error 10.00
# Epoch    98, training loss 0.039908, training error 0.68, validation loss 0.424861, validation error 9.90
# Epoch    99, training loss 0.039604, training error 0.60, validation loss 0.423927, validation error 9.80
