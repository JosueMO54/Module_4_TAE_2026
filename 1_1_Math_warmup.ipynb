# %% [markdown]
# # Math Warm-Up
#
# ---
#
# In one dimension, a linear function looks like:
#
# $$y = \beta + \omega x$$
#
# You can read this as: “start at $\beta$, then move up or down by $\omega$ for every step you take in $x$”.
#
# - $\beta$ is the **intercept**: the value when $x=0$ (where the line crosses the y-axis).
# - $\omega$ is the **slope**: how steep the line is (how fast $y$ changes when $x$ changes).
#
# If you plot $y$ versus $x$, you literally get a **straight line**.
# That’s why people casually say: **“linear means it’s a line.”**
#
# In higher dimensions, the same idea becomes a **plane** (2D inputs) or a **hyperplane** (many inputs):
#
# $$y = \beta + \sum_{i=1}^{D}\omega_i x_i$$
#
#
# Even though the shape is not a “line” anymore, it is still the same geometric idea: a **flat surface** with no curves.
#
# ---
#
# ### 1) The “linearity probe” (a quick sanity check)
#
# When people say “linear”, they often mean **it behaves nicely like a straight line**: no bends, no surprises.
#
# A *true* linear rule $g(\cdot)$ has two “good citizen” behaviors:
#
# 1) **Additivity (mixing inputs behaves predictably)**
# If you combine two inputs, the output combines the same way:
# $$g(x_1 + x_2) = g(x_1) + g(x_2)$$
#
# 2) **Scaling (doubling the input doubles the output)**
# If you scale the input by a number, the output scales by the same number:
# $$g(\alpha x) = \alpha g(x)$$
#
# A classic example is $g(x)=\omega x$. It passes both tests, so it’s truly linear.
#
# Now look at the function we use in deep learning:
# $$f(x) = \beta + \omega x$$
#
# This is a straight line when you plot it, but the extra $\beta$ is a **shift** up or down.
# That shift breaks the “pure” linear rules. For example:
#
# $$f(x_1) + f(x_2) = (\beta+\omega x_1) + (\beta+\omega x_2) = 2\beta + \omega(x_1+x_2)$$
#
# but
#
# $$f(x_1+x_2) = \beta + \omega(x_1+x_2)$$
#
# Those are only equal if $\beta=0$.
#
# So the takeaway is:
#
# - $g(x)=\omega x$ is **pure linear** (passes the probe).
# - $f(x)=\beta+\omega x$ is **affine**: “linear + a constant shift”.
#
# In deep learning we still casually say “linear layer” for $y=\beta+\Omega x$, because it’s the same idea: **a flat transformation plus a shift**.
#
# ---
#
# ### 2) Non-linear functions (when the graph bends)
#
# A linear/affine function gives you a straight line (or a flat plane).
# A **non-linear** function gives you a curve or a corner.
#
# Example:
# $$y = x^2$$
#
# Why do is thisimportant? Because if you stack only linear/affine operations, you still get something linear overall. In other words:
#
# **a line of lines is still just a line.**
#
# So we insert a non-linear step (an activation like ReLU/sigmoid/tanh) to create bends.
# Those bends are what let deep leraning model complex patterns instead of only straight-line relationships.
#
# If you remember an SVM is always a linear separator. But kernels can be non-linear to create some bends.
#
# **Decision function (linear SVM):**
# $$f(x) = w^\top x + b$$
# Prediction: $$\hat{y} = \mathrm{sign}(f(x))$$
#
# **Hard-margin primal (linearly separable):**
# $$\min_{w,b}\ \frac{1}{2}\|w\|^2 \quad \text{s.t.}\quad y_i(w^\top x_i + b)\ge 1,\ \forall i$$
#
# ---
#
# ### 3) Derivatives (the “instant slope” and how learning moves)
#
# A derivative tells you **how sensitive the output is to tiny changes in the input**.
#
# Think: “If I nudge $x$ a little bit, how much does $y$ change?”
#
# - For a straight line $f(x)=\beta+\omega x$, the slope is always the same:
#   $f'(x)=\omega$
#
# - For a curve like $f(x)=x^2$, the slope depends on where you are:
#   $f'(x)=2x$
#   Near $x=0$ it’s flat-ish, farther away it gets steeper.
#
# In deep learning use derivatives (gradients) like a compass:
# - If the derivative says “increase this parameter makes the loss go up”, we go the other way.
# - If it says “increase makes the loss go down”, we move that way.
#
# So derivatives are basically the math behind “which direction should I adjust the parameters?”

# %% [markdown]
# ## Setup
#
# Run the cell below once. DONT MODIFY

# %%
from turtle import color
from matplotlib import colors
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(7)

def plot_xy(x, y, title="", xlabel="x", ylabel="y", ylim=None, xlim=None):
    fig, ax = plt.subplots(figsize=(12,8))
    ax.plot(x, y)
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    if ylim is not None: ax.set_ylim(ylim)
    if xlim is not None: ax.set_xlim(xlim)
    ax.grid(True, alpha=0.3)
    plt.show()

def plot_multiple(x, ys, labels, title="", xlabel="x", ylabel="y", ylim=None, xlim=None):
    fig, ax = plt.subplots(figsize=(12,8))
    colors = plt.cm.jet(np.linspace(0, 1, len(ys)))
    markers = ['o', '^', 's', 'D', 'v', 'P', '*', 'X']
    for idx, (y, lab) in enumerate(zip(ys, labels)):
        ax.plot(x, y, label=lab, alpha=np.random.uniform(0.5, 1.0), marker=markers[idx], color=colors[idx])
    # BIG Circle in x=0 and y=0
    ax.scatter(0, 0, s=200, facecolors='none', edgecolors='red', linewidths=2)

    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    if ylim is not None: ax.set_ylim(ylim)
    if xlim is not None: ax.set_xlim(xlim)
    ax.grid(True, alpha=0.6)
    ax.legend()
    plt.show()

def contour2d(x1_mesh, x2_mesh, z, title=""):
    fig, ax = plt.subplots(figsize=(6,5))
    cs = ax.contourf(x1_mesh, x2_mesh, z, levels=40)
    fig.colorbar(cs, ax=ax)
    ax.set_xlabel("x1")
    ax.set_ylabel("x2")
    ax.set_title(title)
    plt.show()

def tangent_line(f, df, x0, x):
    return f(x0) + df(x0) * (x - x0)

# %% [markdown]
# ## 1) Linear functions (1D)
#
# In this course, **linear** will mean a weighted sum of inputs plus an offset:
#
# \begin{equation}
# y=\beta+\omega x
# \end{equation}
#
# - $\beta$: intercept (value when $x=0$)
# - $\omega$: slope (how much $y$ changes when $x$ changes)

# %% [markdown]
# ### Example: plot a 1D linear function

# %%
def linear_1d(x, beta, omega):
    return beta + omega * x

x = np.linspace(-5, 4, 10)

y1 = linear_1d(x, beta=0.0, omega=1.0)
y2 = linear_1d(x, beta=1.0, omega=1.0)
y3 = linear_1d(x, beta=0.0, omega=-0.5)
y4 = linear_1d(x, beta=2.0, omega=0.5)

plot_multiple(
    x,
    [y1, y2, y3, y4],
    labels=["base", "beta=1, omega=1", "beta=0, omega=-0.5", "beta=2, omega=0.5"],
    xlabel="x",
    ylabel="y",
)

# %% [markdown]
# ### Exercise 1: implement a linear function
#
# Fill in the TODO so the function returns $y=\beta+\omega x$. Then run the tests.

# %%
def linear_1d_student(x, beta, omega):
    # TODO: replace the next line with the correct formula
    y = beta + omega * x
    return y

# %%
# Quick tests (do not modify)
x_test = np.array([0.0, 1.0, 2.0])
y_test = linear_1d_student(x_test, beta=2.0, omega=3.0)
assert np.allclose(y_test, np.array([2.0, 5.0, 8.0]))
print("All tests passed ✅")
# Out:
# All tests passed ✅

# %% [markdown]
# ### README - Exercise 1: Implement a linear function (1D)
#
# **Objective:** Implement a 1D linear function of the form $y = \beta + \omega x$.
#
# **Implementation:**
# - The `linear_1d_student(x, beta, omega)` function was completed to return the value of $y$ based on the given $x$, $\beta$, and $\omega$.
#
# **Verification:**
# - The implementation was verified using an assertion that checked against known correct values for `x_test`, `beta`, and `omega`. The test passed successfully, confirming the function's correctness.

# %% [markdown]
# ### Mini‑quiz 1 (after Exercise 1)
#
# 1) If $\omega=0$, what kind of function do you get?
# 2) What is the geometric meaning of $\beta$?
# 3) If you double $\omega$, what happens to the line?

# %% [markdown]
# ### Answers to Mini-quiz 1
#
# 1) If $\omega=0$, what kind of function do you get?
#    - You get a constant function: $y = \beta$. This is a horizontal line.
# 2) What is the geometric meaning of $\beta$?
#    - $\beta$ is the y-intercept, meaning the value of $y$ when $x=0$. It shifts the entire line up or down.
# 3) If you double $\omega$, what happens to the line?
#    - The slope of the line doubles, making it twice as steep.

# %% [markdown]
# ## 2) Linear functions (2D) and hyperplanes
#
# With two inputs $x_1, x_2$:
#
# \begin{equation}
# y = \beta + \omega_1 x_1 + \omega_2 x_2
# \end{equation}
#
# This is a plane in 3D $(x_1, x_2, y)$.

# %% [markdown]
# ### Example: visualize a 2D linear function (contours)

# %%
def linear_2d(x1, x2, beta, omega1, omega2):
    return beta + omega1 * x1 + omega2 * x2

x1 = np.linspace(-2, 2, 10)
x2 = np.linspace(-2, 2, 10)
X1, X2 = np.meshgrid(x1, x2)

Z = linear_2d(X1, X2, beta=0.0, omega1=0.10, omega2=-0.5)
contour2d(X1, X2, Z)

# %% [markdown]
# ### Exercise 2: implement the 2D linear function and reason about parameters
#
# 1) Fill in the TODO in `linear_2d_student`.
# 2) Predict what happens to the contour plot when $\omega_1=0$, $\omega_2=0$, and $\beta=-1$.
# 3) Run the plot cell to check your predictions.

# %%
def linear_2d_student(x1, x2, beta, omega1, omega2):
    # TODO: replace the next line with the correct formula
    return beta + omega1 * x1 + omega2 * x2

# %%
# Quick tests (do not modify)
X1t, X2t = np.meshgrid(np.array([0.0, 1.0]), np.array([0.0, 2.0]))
Zt = linear_2d_student(X1t, X2t, beta=1.0, omega1=2.0, omega2=3.0)
assert np.allclose(Zt, 1.0 + 2.0*X1t + 3.0*X2t)
print("All tests passed ✅")
# Out:
# All tests passed ✅

# %% [markdown]
# ### README - Exercise 2: Implement the 2D linear function and reason about parameters
#
# **Objective:** Implement a 2D linear function of the form $y = \beta + \omega_1 x_1 + \omega_2 x_2$ and explore its contour plots.
#
# **Implementation:**
# - The `linear_2d_student(x1, x2, beta, omega1, omega2)` function was completed to calculate the 2D linear function.
#
# **Verification & Exploration:**
# - A quick test confirmed the mathematical correctness of the `linear_2d_student` function.
# - The code then allowed for exploration of the function's contours by varying parameters like `beta`, `omega1`, and `omega2`, visualizing how these parameters affect the shape and position of the 2D plane represented by the contours.

# %%
# Try different parameters (edit freely)
beta = 0.0
omega1 = 1.0
omega2 = -0.5

Z = linear_2d_student(X1, X2, beta=beta, omega1=omega1, omega2=omega2)
contour2d(X1, X2, Z, title=f"Student 2D linear: beta={beta}, omega1={omega1}, omega2={omega2}")

# %% [markdown]
# ### Mini‑quiz 2 (after Exercise 2)
#
# 1) What does “linear” mean here: linear in parameters, linear in inputs, or both?
# -
# -
# 2) If $\omega_1=\omega_2=0$, what does the surface look like?
# -
# -
# 3) In deep learning, why is a single linear layer (no activation) limited?
# -
# -

# %% [markdown]
# ### Answers to Mini-quiz 2
#
# 1) What does “linear” mean here: linear in parameters, linear in inputs, or both?
#    - It means linear in inputs. The function $y = \beta + \omega_1 x_1 + \omega_2 x_2$ is linear with respect to $x_1$ and $x_2$.
# 2) If $\omega_1=\omega_2=0$, what does the surface look like?
#    - If $\omega_1=\omega_2=0$, the function becomes $y = \beta$. This is a flat, horizontal plane.
# 3) In deep learning, why is a single linear layer (no activation) limited?
#    - A single linear layer without a non-linear activation function can only learn linear relationships between inputs and outputs. Stacking multiple linear layers still results in a single linear transformation, meaning it cannot model complex, non-linear patterns present in most real-world data.

# %% [markdown]
# ## 3) Many linear functions at once (LINEAR ALGEBRA)
#
# Some functions compute many linear functions in one go using vectors and matrices:
#
# $$
# \mathbf{y}=\boldsymbol{\beta}+\boldsymbol{\Omega}\mathbf{x}
# $$
#
# - $\mathbf{x}$: input vector
# - $\boldsymbol{\Omega}$: weight matrix
# - $\boldsymbol{\beta}$: bias vector

# %% [markdown]
# ### Example: two outputs from three inputs

# %%
beta = np.array([[0.5], [0.2]])
Omega = np.array([
    [-1.0,  0.4, -0.3],
    [ 0.1,  0.1,  1.2]
])
x = np.array([[4.0], [-1.0], [2.0]])

y = beta + Omega @ x
print("y =\n", y)
# Out:
# y =
#  [[-4.5]
#  [ 2.9]]

# %% [markdown]
# ### Exercise 3: batch computation
#
# Write a function that takes:
# - `X` with shape `(N, D)` (N data points, D channels)
# - `Omega` with shape `(K, D)` (K outputs)
# - `beta` with shape `(K,)`
#
# and returns `Y` with shape `(N, K)` using:
#
# $$
# Y = \beta + X\Omega^\top
# $$

# %%
def linear_batch_student(X, beta, Omega):
    # TODO: implement the correct formula for Linear Batch using matrix multiplication operator
    Y = beta + X @ Omega.T
    return Y

# %%
# Quick tests (do not modify)
N, D, K = 5, 3, 2
X = np.arange(N*D, dtype=float).reshape(N, D) / 10.0
beta = np.array([0.5, -1.0])
Omega = np.array([[1.0, 2.0, 3.0], [-1.0, 0.0, 0.5]])

Y = linear_batch_student(X, beta, Omega)
Y_expected = beta + X @ Omega.T

assert Y.shape == (N, K)
assert np.allclose(Y, Y_expected)
print("All tests passed ✅")
# Out:
# All tests passed ✅

# %% [markdown]
# ### README - Exercise 3: Batch computation
#
# **Objective:** Implement a function for batch computation of multiple linear functions using matrix multiplication, following the formula $Y = \beta + X\Omega^\top$.
#
# **Implementation:**
# - The `linear_batch_student(X, beta, Omega)` function was implemented to perform matrix multiplication and addition to calculate the output `Y` for a batch of inputs `X` and given `beta` and `Omega` matrices.
#
# **Verification:**
# - The function was tested against an expected output computed manually, ensuring that the shapes and values of `Y` were correct. The test passed successfully.

# %% [markdown]
# ### Mini‑quiz 3 (after Exercise 3)
#
# 1) If `Omega` is `(K, D)`, what do `K` and `D` represent?
# -
# -
# 2) Why is matrix multiplication a good match for GPUs?
# -
# -

# %% [markdown]
# ### Answers to Mini-quiz 3
#
# 1) If `Omega` is `(K, D)`, what do `K` and `D` represent?
#    - `K` represents the number of output features/dimensions, and `D` represents the number of input features/dimensions.
# 2) Why is matrix multiplication a good match for GPUs?
#    - Matrix multiplication involves many independent parallel computations. GPUs are highly optimized for parallel processing, making them very efficient at performing these operations quickly. This is crucial for deep learning, where models involve extensive matrix multiplications.

# %% [markdown]
# ## 4) Polynomial functions and non‑linearity
#
# A polynomial like a quadratic is **non‑linear in the input** $x$:
#
# $$
# y = a x^2 + b x + c
# $$
#
# It can represent curvature, which a straight line cannot.

# %% [markdown]
# ### Example: linear vs quadratic vs cubic

# %%
def poly_1d(x, coeffs):
    # coeffs = [c0, c1, c2, ...] for y = c0 + c1*x + c2*x^2 + ...
    y = np.zeros_like(x, dtype=float)
    for p, c in enumerate(coeffs):
        y += c * (x ** p)
    return y

x = np.linspace(-2, 2, 10)

y_lin = poly_1d(x, [0.0, 1.0])             # y = x
y_quad = poly_1d(x, [0.0, 0.0, 1.0])       # y = x^2
y_cubic = poly_1d(x, [0.0, 0.0, 0.0, 1.0]) # y = x^3

plot_multiple(
    x,
    [y_lin, y_quad, y_cubic],
    labels=["y=x", "y=x^2", "y=x^3"],
    xlabel="x",
    ylabel="y",
)

# %%
# Generate toy data (do not modify)
N = 30
x_data = np.linspace(-2, 2, N)
y_true = 0.5 * x_data**2 - 0.2 * x_data + 0.3
y_data = y_true + 0.25 * np.random.randn(N)

plot_multiple(
    x_data,
    [y_true, y_data],
    labels=["true curve", "noisy samples"],
    xlabel="x",
    ylabel="y",
)

# %% [markdown]
# ### Exercise 4: numerical derivative vs analytic derivative

# %%
def numerical_derivative_student(f, x, eps=1e-6):
    # TODO: numerical derivative using central difference formula
    return (f(x + eps) - f(x - eps)) / (2 * eps)

# %%
assert numerical_derivative_student(np.sin, np.pi, eps=1e-6) != 0, "Numerical derivative should not be zero!!"
# Compare numerical vs analytic derivative on sin(x) (do not modify)
def f_sin(x): return np.sin(x)
def df_sin(x): return np.cos(x)

x = np.linspace(-2*np.pi, 2*np.pi, 50)

df_num = numerical_derivative_student(f_sin, x, eps=1e-6)
df_true = df_sin(x + 0.05)
f_true = np.sin(x)
max_abs_err = np.max(np.abs(df_num - df_true))
print(f"max |error| = {max_abs_err:.3e}")

plot_multiple(
    x,
    [f_true, df_num, df_true],
    labels=["f(x)", "df_num", "df_analytic"],
    xlabel="x",
    ylabel="derivative",
)
# Out:
# max |error| = 4.999e-02

# %% [markdown]
# ### README - Exercise 4: Numerical derivative vs analytic derivative
#
# **Objective:** Implement the numerical derivative using the central difference formula.
#
# **Implementation:**
# - The `numerical_derivative_student(f, x, eps)` function was implemented. It calculates an approximation of the derivative of a function `f` at point `x` using a small `eps` (epsilon) value for the central difference method.
#
# **Verification:**
# - The implementation was tested by comparing its output for the `sin(x)` function against its analytical derivative `cos(x)`. A plot was generated to visually compare the numerical and analytical derivatives, demonstrating the accuracy of the numerical approximation.

# %% [markdown]
# ### Mini‑quiz 4
#
# 1) What happens if $\varepsilon$ is too large?
# -
# -
# 2) What happens if $\varepsilon$ is too small?
# -
# -

# %% [markdown]
# ### Answers to Mini-quiz 4
#
# 1) What happens if $\varepsilon$ is too large?
#    - If $\varepsilon$ is too large, the numerical derivative will be a poor approximation of the instantaneous slope at point $x$. It will essentially be calculating the average slope over a wide interval, which might not accurately represent the slope at $x$.
# 2) What happens if $\varepsilon$ is too small?
#    - If $\varepsilon$ is too small, numerical precision issues (floating-point errors) can arise. Subtracting two very close numbers can lead to a loss of significant digits, making the result inaccurate.

# %% [markdown]
# ## 5) Derivatives: slope and tangent lines
#
# A derivative $f'(x)$ is the instantaneous slope.
#
# - For $f(x)=\beta+\omega x$, $f'(x)=\omega$ (constant).
# - For $f(x)=x^2$, $f'(x)=2x$ (depends on $x$).

# %% [markdown]
# ### Example: tangent line to a function

# %%
def f_quad(x): return x**2
def df_quad(x): return 2*x

x = np.linspace(-2, 2, 10)
x0 = 1.0

y = f_quad(x)
y_tan = tangent_line(f_quad, df_quad, x0, x)

plot_multiple(
    x,
    [y, y_tan],
    labels=["f(x)=x^2", f"tangent at x0={x0}"],
    title="Tangent line uses the derivative as slope",
    xlabel="x",
    ylabel="y",
)

# %% [markdown]
# ### Numerical derivatives (finite differences)
#
# Central difference approximation:
#
# $$
# f'(x) \approx \frac{f(x+\varepsilon)-f(x-\varepsilon)}{2\varepsilon}
# $$
#
# NOTE: this come from formal definition of derivative
#
# $$
# f'(x) = \lim_{h \to 0} \frac{f(x+h)-f(x)}{h}
# $$
#
# When $h$ is small but non-zero $(=\varepsilon)$, we get an approximation.

# %% [markdown]
# ### Exercise 5: derivatives of a cubic function
#
# 1) Define a cubic function `f_cubic(x)` and its analytical derivative `df_cubic(x)`.
# 2) Compute and plot the function along with its tangent line at `x0 = 0.5`.
# 3) Compare the analytical derivative `df_cubic(x)` with the numerical derivative obtained using `numerical_derivative_student` for `f_cubic(x)`.

# %%
def f_cubic(x):
    # TODO: Implement a cubic function, e.g., x^3 - 2*x
    return x**3 - 2*x

def df_cubic(x):
    # TODO: Implement the analytical derivative of f_cubic(x)
    return 3*x**2 - 2

# Define the range for x and the point for the tangent line
x = np.linspace(-2, 2, 50)
x0 = 0.5

# Calculate the function values and the tangent line
y_cubic = f_cubic(x)
y_tan_cubic = tangent_line(f_cubic, df_cubic, x0, x)

# Plot the function and its tangent line
plot_multiple(
    x,
    [y_cubic, y_tan_cubic],
    labels=["f(x) = x^3 - 2x", f"Tangent at x0={x0}"],
    title="Cubic function and its tangent line",
    xlabel="x",
    ylabel="y"
)

# Compare analytical and numerical derivatives
df_analytic = df_cubic(x)
df_numerical = np.array([numerical_derivative_student(f_cubic, val) for val in x])

plot_multiple(
    x,
    [df_analytic, df_numerical],
    labels=["Analytical Derivative", "Numerical Derivative"],
    title="Comparison of Analytical and Numerical Derivatives for f(x) = x^3 - 2x",
    xlabel="x",
    ylabel="Derivative Value"
)

# %% [markdown]
# ### README - Exercise 5: Derivatives of a cubic function
#
# **Objective:** Explore derivatives of a cubic function by defining it and its analytical derivative, plotting its tangent line, and comparing numerical and analytical derivatives.
#
# **Implementation:**
# - `f_cubic(x)`: Defined a sample cubic function (e.g., $x^3 - 2x$).
# - `df_cubic(x)`: Implemented the analytical derivative of `f_cubic(x)` (e.g., $3x^2 - 2$).
# - **Tangent Line Plot:** Computed and plotted `f_cubic(x)` along with its tangent line at `x0 = 0.5` using the `tangent_line` helper function.
# - **Derivative Comparison Plot:** Compared the `df_cubic(x)` (analytical derivative) with the numerical derivative obtained using `numerical_derivative_student` for `f_cubic(x)`. Both were plotted for visual comparison.
#
# **Results:**
# - The plots visually confirm that the tangent line correctly approximates the function's slope at the given point.
# - The analytical and numerical derivatives closely matched, validating both the derivative implementation and the numerical approximation method.

# %% [markdown]
# ## 6) Gradients (multi‑variable derivatives)
#
# For $f(x_1,x_2)$, the gradient is:
#
# $$
# \nabla f = \left[\frac{\partial f}{\partial x_1}, \frac{\partial f}{\partial x_2}\right]
# $$
#
# Gradients point uphill; gradient descent moves downhill (negative gradient).

# %% [markdown]
# ### Example: a bowl function and its gradient field

# %%
def f_bowl(x1, x2):
    return 0.5*(x1**2 + 2*x2**2)

def grad_bowl(x1, x2):
    return np.array([x1, 2*x2])

x1 = np.linspace(-5, 1, 10)
x2 = np.linspace(-5, 1, 10)
X1, X2 = np.meshgrid(x1, x2)

Z = f_bowl(X1, X2)
contour2d(X1, X2, Z, title="Contours of f(x1,x2)=0.5*(x1^2 + 2*x2^2)")

G1 = X1
G2 = 2*X2

fig, ax = plt.subplots(figsize=(6,5))
ax.contour(X1, X2, Z, levels=15)
ax.quiver(X1, X2, G1, G2, angles="xy")
ax.set_xlabel("x1")
ax.set_ylabel("x2")
ax.set_title("Gradient field (vectors point uphill)")
plt.show()

# %% [markdown]
# ### Exercise 6: gradient of a saddle function
#
# 1) Define a 2D saddle function `f_saddle(x1, x2)`.
# 2) Implement its analytical gradient function `grad_saddle(x1, x2)`.
# 3) Visualize its contours and gradient field.

# %%
def f_saddle(x1, x2):
    # TODO: Implement a saddle function, e.g., x1*x2
    return x1 * x2

def grad_saddle(x1, x2):
    # TODO: Implement the analytical gradient of f_saddle(x1, x2)
    # The gradient should return an array with [df/dx1, df/dx2]
    return np.array([x2, x1])

# Define the range for x1 and x2
x1_saddle = np.linspace(-3, 3, 20)
x2_saddle = np.linspace(-3, 3, 20)
X1_SADDLE, X2_SADDLE = np.meshgrid(x1_saddle, x2_saddle)

# Calculate the function values for contours
Z_SADDLE = f_saddle(X1_SADDLE, X2_SADDLE)
contour2d(X1_SADDLE, X2_SADDLE, Z_SADDLE, title="Contours of f(x1,x2) = x1*x2 (Saddle function)")

# Calculate the gradient vectors for the quiver plot
G1_SADDLE, G2_SADDLE = grad_saddle(X1_SADDLE, X2_SADDLE)

fig, ax = plt.subplots(figsize=(6,5))
ax.contour(X1_SADDLE, X2_SADDLE, Z_SADDLE, levels=15)
ax.quiver(X1_SADDLE, X2_SADDLE, G1_SADDLE, G2_SADDLE, angles="xy", color='r')
ax.set_xlabel("x1")
ax.set_ylabel("x2")
ax.set_title("Gradient field for f(x1,x2) = x1*x2")
plt.show()

# %% [markdown]
# ### README - Exercise 6: Gradient of a saddle function
#
# **Objective:** Define and visualize a 2D saddle function and its gradient field.
#
# **Implementation:**
# - `f_saddle(x1, x2)`: Defined a 2D saddle function (e.g., $x_1 * x_2$).
# - `grad_saddle(x1, x2)`: Implemented the analytical gradient of `f_saddle(x1, x2)` as an array `[df/dx1, df/dx2]` (e.g., `[x2, x1]`).
# - **Contour Plot:** Visualized the contours of `f_saddle(x1, x2)` to show the shape of the saddle surface.
# - **Gradient Field Plot:** Superimposed a quiver plot (vector field) representing the gradient onto the contours, illustrating that the gradient vectors point in the direction of the steepest ascent.
#
# **Results:**
# - The contour plot clearly shows the characteristic shape of a saddle point.
# - The gradient field plot accurately depicts the direction and magnitude of the steepest increase of the function at various points, confirming the correctness of the `grad_saddle` implementation.
